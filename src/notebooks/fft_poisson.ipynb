# %% [markdown]
# # Poisson solution with FFT
#
# ## General Problem
#
# As a subroutine for the main algorithm. We need the ability to solve Poisson differential equations. In other words, equations of the form
#
# $$
# \begin{align*}
# \Delta \phi(x, y, z) &= f(x, y, z), \forall (x, y, z) \in [0, L_x] \times [0, L_y] \times [0, L_z] \\
# \phi (0, y) &= \phi (L_x, y), \phi (x, 0) = \phi (x, L_y) \\
# \phi_x (0, y) &= \phi_x (L_x, y), \phi_y (x, 0) = \phi_y (x, L_y) \\
# \end{align*}
# $$,
#
# a Poisson equation with periodic boundary constraints.
# To simplify the problem without much loss for generality, we set $L_x = L_y = L_z = 1$. Therefore, the domain $\Omega = [0, 1]^3$.
# However, due to the periodic boundary conditions on the solution $\phi$, the domain is more precisely the 3-torus, $\mathbb{T}^3 = \Omega$.
#
# ## Specific example problem
#
# The specific example problem we solve to ensure our solver works correctly is
#
# $f(x, y, z) = \cos (2  \pi x) + \sin(2\pi y) + \sin(2\pi z)\cos(2\pi x)$
#
# ### Solution
#
# The textbook way of solving these types of differential equations is to consider a Fourier series expansion forms of the functions $\phi$ and $f$.
#
# ### Discretization
#
# However, as we're dealing with discrete data points, we only have access to the function values at specific points.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
L = 1.0
N = 51
x, y, z = np.linspace(0, L, N), np.linspace(0, L, N), np.linspace(0, L, N)
grid = np.meshgrid(x, y, z)
X, Y, Z = grid

# %%
points = np.asarray([[[[x, y, z] for x in x] for y in y] for z in z])
points.shape
# Out:
# (51, 51, 51, 3)

# %%
def RHS(X, Y, Z):
    return np.sin(2*np.pi*Y) + np.cos(4 * np.pi * X) # - np.sin(2*np.pi*Y) + np.sin(2*Z*np.pi) * np.cos(2 * np.pi * X)
f = RHS(X, Y, Z)

# %%
# Create the heightmap plot
fig = plt.subplots(1, 1, figsize=(10, 8))
plt.contourf(X[:, :, 0], Y[:, :, 0], f[:, :, 0], levels=80, cmap='inferno')
plt.colorbar(label='f(x, y, 0)')
plt.title('Heatmap of $f(x, y, 0)$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %% [markdown]
# The above plot shows the values of function $f$ on the domain $\Omega' = \pi_z(\Omega)$ which is the projection of the original domain $\Omega$ to the $xy$-plane.

# %% [markdown]
# ## Solution

# %%
f_hat = np.fft.fftn(f)
f_hat.shape
# Out:
# (51, 51, 51)

# %%
f_hat_norm = np.absolute(f_hat)

# %%
# Calculate the necessary frequencies for each dimension:
k_x = np.fft.fftfreq(N, d=1/N)
k_y = np.fft.fftfreq(N, d=1/N) 
k_z = np.fft.fftfreq(N, d=1/N) 

K = np.asarray([[[[k_xi, k_yi, k_zi] for k_xi in k_x] for k_yi in k_y] for k_zi in k_z])
K.shape
# Out:
# (51, 51, 51, 3)

# %%
plt.scatter(k_x, f_hat_norm[:, 0, 0])

# %%
plt.scatter(k_y, f_hat_norm[0, :, 0])

# %%
# Solving x_hat
norm_K = np.linalg.norm(K, axis=-1)

# Add small epsilon
norm_K = norm_K

x_hat = f_hat / (-4*np.pi**2*norm_K**2 + 1E-9) # Important! Keep this when defining wavenumbers without 2*pi constants.
x_hat[0, 0, 0] = 0
print(x_hat)
x_hat_norm = np.absolute(x_hat)
# Out:
# [[[ 0.00000000e+00+0.00000000e+00j -0.00000000e+00-0.00000000e+00j
#    -0.00000000e+00-0.00000000e+00j ...  1.41783150e-17-0.00000000e+00j
#    -0.00000000e+00-0.00000000e+00j -0.00000000e+00-0.00000000e+00j]
#   [-8.65039943e+01-5.33538374e+00j -0.00000000e+00-0.00000000e+00j
#    -0.00000000e+00-0.00000000e+00j ...  3.11278145e-16-2.48709339e-17j
#    -0.00000000e+00-0.00000000e+00j -0.00000000e+00-0.00000000e+00j]
#   [-4.19890855e+02-5.19937556e+01j -0.00000000e+00-0.00000000e+00j
#    -0.00000000e+00-0.00000000e+00j ...  5.06336052e-15+5.00582548e-16j
#    -0.00000000e+00-0.00000000e+00j -0.00000000e+00-0.00000000e+00j]
#   ...
#   [ 6.15382529e+00-1.15034931e+00j -0.00000000e+00-0.00000000e+00j
#    -0.00000000e+00-0.00000000e+00j ... -1.26801536e-16+2.28385179e-17j
#    -0.00000000e+00-0.00000000e+00j -0.00000000e+00-0.00000000e+00j]
#   [-4.19890855e+02+5.19937556e+01j -0.00000000e+00-0.00000000e+00j
#    -0.00000000e+00-0.00000000e+00j ...  5.06336052e-15-5.00582548e-16j
# ...

# %%
solution = np.fft.ifftn(x_hat)
solution.shape
# Out:
# (51, 51, 51)

# %%
fig = plt.subplots(1, 1, figsize=(10, 8))
plt.contourf(X[:, :, 0], Y[:, :, 0], solution[:, :, 0], levels=80, cmap='inferno')
plt.colorbar(label='f(x, y, 0)')
plt.title('Heatmap of $f(x, y, 0)$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()
# Out:
# /home/tuomas/miniconda3/envs/minimal_surface/lib/python3.10/site-packages/matplotlib/contour.py:1519: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.zmax = z.max().astype(float)
# /home/tuomas/miniconda3/envs/minimal_surface/lib/python3.10/site-packages/matplotlib/contour.py:1520: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.zmin = z.min().astype(float)
# /home/tuomas/miniconda3/envs/minimal_surface/lib/python3.10/site-packages/numpy/ma/core.py:2892: ComplexWarning: Casting complex values to real discards the imaginary part
#   _data = np.array(data, dtype=dtype, copy=copy,

# %% [markdown]
# ## Checking solution
#
# The analytical solution to our 2-dimensional example problem is

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the problem
L = 1.0             # Length of the domain
N = 128             # Number of grid points (power of 2 for FFT)
dx = L / N          # Grid spacing
x = np.linspace(0, L, N, endpoint=False)  # Grid points

# Right-hand side function f(x)
f = np.sin(2 * np.pi * x)

# Compute the DFT of f(x) using FFT
f_hat = np.fft.fft(f)

# Define the wavenumbers (frequencies)
k = np.fft.fftfreq(N, d=dx)

# Solve for u_hat in Fourier space
u_hat = np.zeros(N, dtype=complex)
k_squared = k**2
nonzero_k = k != 0  # Avoid division by zero
u_hat[nonzero_k] = f_hat[nonzero_k] / (-4*np.pi**2*k_squared[nonzero_k])

# Transform back to real space to get u(x)
u = np.fft.ifft(u_hat).real

# Analytical solution
u_exact = -(1 / (2 * np.pi)**2) * np.sin(2 * np.pi * x)

# Plot the results
plt.plot(x, u, label="Numerical Solution (DFT)", marker="o", linestyle="none")
plt.plot(x, u_exact, label="Analytical Solution")
plt.xlabel("x")
plt.ylabel("u(x)")
plt.legend()
plt.title("1D Poisson Equation Solved Using DFT")
plt.grid()
plt.show()

# Compute the error
error = np.linalg.norm(u - u_exact, np.inf)
print(f"Maximum error: {error:.5e}")
# Out:
# Maximum error: 1.21431e-17

# %%
import numpy as np
import matplotlib.pyplot as plt

# Domain setup
Lx, Ly = 1.0, 1.0  # Domain size
Nx, Ny = 128, 128  # Number of grid points
dx, dy = Lx / Nx, Ly / Ny  # Grid spacing
x = np.linspace(0, Lx, Nx, endpoint=False)
y = np.linspace(0, Ly, Ny, endpoint=False)
X, Y = np.meshgrid(x, y)

# Define the forcing term
f = np.cos(4 * np.pi * X) + np.sin(2 * np.pi * Y)

# Compute the 2D FFT of f
f_hat = np.fft.fft2(f)

# Define the wavenumbers
kx = 2 * np.pi * np.fft.fftfreq(Nx, d=dx)
ky = 2 * np.pi * np.fft.fftfreq(Ny, d=dy)
kx, ky = np.meshgrid(kx, ky)

# Compute the denominator (k_x^2 + k_y^2), avoid division by zero
k_squared = kx**2 + ky**2
k_squared[0, 0] = 1  # Avoid dividing by zero for the (0, 0) mode

# Solve in Fourier space
u_hat = -f_hat / k_squared
u_hat[0, 0] = 0  # Ensure zero mean for u

# Transform back to real space
u = np.fft.ifft2(u_hat).real

# Analytical solution for verification
u_exact = -(1 / (4 * np.pi)**2) * np.cos(4 * np.pi * X) - (1 / (2 * np.pi)**2) * np.sin(2 * np.pi * Y)

# Plot the results
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.contourf(X, Y, u, levels=50, cmap="inferno")
plt.colorbar(label="u(x, y)")
plt.title("Numerical Solution (DFT)")
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(1, 2, 2)
plt.contourf(X, Y, u_exact, levels=50, cmap="inferno")
plt.colorbar(label="u(x, y)")
plt.title("Analytical Solution")
plt.xlabel("x")
plt.ylabel("y")

plt.tight_layout()
plt.show()

# Compute the error
error = np.linalg.norm(u - u_exact, np.inf)
print(f"Maximum error: {error:.5e}")
# Out:
# Maximum error: 1.57686e-15
